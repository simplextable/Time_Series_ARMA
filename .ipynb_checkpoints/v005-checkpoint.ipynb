# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from statsmodels.tsa.stattools import adfuller
from matplotlib import pyplot
from math import sqrt
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pmd
# Out:
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
df = pd.read_csv("data_final.csv")

# %%
df = df[["y7"]]

# %%
df
# Out:
#             y7
# 0    -2.442986
# 1    -1.233039
# 2    -0.160485
# 3     0.923501
# 4     0.951432
# ...        ...
# 1495  1.389197
# 1496 -0.165867
# 1497 -0.531916
# 1498  0.007447
# 1499 -0.331146
#
# [1500 rows x 1 columns]

# %%
df_train=df[0:1450]

# %%
df_val=df[1450:1500]

# %%
plt.plot(df_train.index, df_train.y7)
#plt.figure(figsize=(100, 6))
figure(figsize=(20, 20), dpi=80)
plt.show()
#grafik genişletilecek

# %%
#BURADA ACF ACF grafiğine baktığımızda geçmiş şokların etkisinin azaldığı, geçmişin hızla unutulduğu  görülmektedir. 
#Buna göre durağan olduğu söylenebilir. ADF birim kök testi ile durağan olup olmadığı belirlenecektir.

# %%
sm.graphics.tsa.plot_acf(df_train.values.squeeze(), lags=40)
plt.show()

# %%
sm.graphics.tsa.plot_pacf(df_train.values.squeeze(), lags=40, method="ywm")
plt.show()

# %%
# ACF VE PACF GRAFİKLERİNE KORELOGRAM DENİLİYOR.

# %%
# Önce grafiklere bakıldı.

# %%
result = adfuller(df_train['y7'])
print('Augmented Dickey-Fuller Test:')
labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']

for value,label in zip(result,labels):
    print(label+' : '+str(value) )
    
if result[1] <= 0.05:
    print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
else:
    print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -10.24466660396661
# p-value : 4.6513646971897194e-18
# #Lags Used : 3
# Number of Observations Used : 1446
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
#STATIONARY OLUP OLMAMASI ARMA - ARIMA MI KULLANILACAĞINI GÖSTERİR.

# %%
#HO HİPOTEZİ REDDEDİLDİĞİ İÇİN BİRİM KÖK YOK. DATA STATİONARY DİYORUZ.

# %%
#ADF TESTİNİN SONUCU OLARAK R'DA 3 TANE TİP GELİYOR. 
#TİP1, TİP2 VE TİP3 ÇALIŞILACAK

# %%
#DF TESTİ YOK.ÇÜNKÜ ADF TESTİ DF'Yİ KAPSIYOR.

# %%
#Ljung-Box Testi: zaman serisi olup olmadığnı anlamak için yapılacak, incelenecek

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

# %%
acorr_ljungbox(df_train["y7"], lags=[20], return_df=True)
# Out:
#         lb_stat  lb_pvalue
# 20  3706.806677        0.0

# %%
### R'da x^2 değeri burada lb_stat olarak geçiyor. p value %5, anlamlılık düzeyinden daha az olduğu için bu datada zaman
### serisi vardır diyebiliriz. 

#Test, residual korelasyonuna bakıyor. 
#H0: absence of serial correlation
#Ha: existance of serial correlation
#p_val < alpha ==> H0 reddedilir

#ZAMAN SERİSİ OLDUĞU İÇİN ARMA MODELİ KULLANILABİLİYOR. 
#Akaike's Information Criterion

# %%
def arimamodel(timeseriesarray):
    autoarima_model = pmd.auto_arima(timeseriesarray, 
                              start_p=1, 
                              start_q=1,
                              test="adf",
                              trace=True)
    return autoarima_model

# %%
arima_model = arimamodel(df_train["y7"])
arima_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4148.031, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=6587.780, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4299.326, Time=0.14 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=5206.118, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=6598.351, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=4149.665, Time=0.33 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=4149.676, Time=0.37 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=4654.401, Time=0.76 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4172.223, Time=0.10 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4150.454, Time=1.88 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=4147.098, Time=0.10 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=5213.823, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4297.976, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=4148.697, Time=0.14 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=4148.706, Time=0.13 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=4659.150, Time=0.34 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4171.458, Time=0.07 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=4150.708, Time=0.12 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 5.106 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1450
# Model:               SARIMAX(1, 0, 1)   Log Likelihood               -2070.549
# Date:                Sat, 22 Oct 2022   AIC                           4147.098
# Time:                        13:38:32   BIC                           4162.936
# Sample:                             0   HQIC                          4153.008
#                                - 1450
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8225      0.017     47.639      0.000       0.789       0.856
# ma.L1          0.3759      0.028     13.469      0.000       0.321       0.431
# sigma2         1.0169      0.039     26.288      0.000       0.941       1.093
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 1.73
# Prob(Q):                              0.81   Prob(JB):                         0.42
# Heteroskedasticity (H):               1.03   Skew:                             0.07
# Prob(H) (two-sided):                  0.73   Kurtosis:                         2.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df_val.head()
# Out:
#    Expected
# 0  1.002199
# 1  2.787295
# 2  2.051013
# 3  1.989426
# 4  1.909431

# %%
df_val.head()
# Out:
#             y7
# 1450  1.002199
# 1451  2.787295
# 1452  2.051013
# 1453  1.989426
# 1454  1.909431

# %%
type(results.fittedvalues)
# Out:
# pandas.core.series.Series

# %%
model = ARIMA(df_val, order=(1,0,1))

results = model.fit()

plt.plot(df[1450:1500])
plt.plot(results.fittedvalues, color='red')

# %%
history = [x for x in df_train.values] #df_valdeki değerler: veri setinin son 50 satırı
predictions = list() #predictionların doldurması için boş liste

for t in range(len(df_val)):
    model = ARIMA(history, order=(1,0,1)) #df_val'i (tahmin edeceğimiz değerler) ARMA(1,1) modeline aktarmış olduk
    model_fit = model.fit() #üst satırdaki "model"i forecast işlemi için fit ediyor
    output = model_fit.forecast() #üst satırda fit edilmiş model için forecast fonsiyonu çalıştırıyor.
    yhat = output[0] #output 3 değer döndürüyor. bunnu 1. değeri sonu. o yüzden indexi 0 olanları yhat'e atıyor.
    predictions.append(yhat) #yhat değerlerini predictions listesine ekliyor
    obs = df_val.values[t] 
    #history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# predicted=0.697860, expected=1.002199
# predicted=0.697860, expected=2.787295
# predicted=0.697860, expected=2.051013
# predicted=0.697860, expected=1.989426
# predicted=0.697860, expected=1.909431
# predicted=0.697860, expected=-1.002516
# predicted=0.697860, expected=-2.584814
# predicted=0.697860, expected=-2.671822
# predicted=0.697860, expected=-3.011653
# predicted=0.697860, expected=-2.797590
# predicted=0.697860, expected=-4.818500
# predicted=0.697860, expected=-6.334692
# predicted=0.697860, expected=-5.800717
# predicted=0.697860, expected=-5.528374
# predicted=0.697860, expected=-5.011379
# predicted=0.697860, expected=-3.881508
# predicted=0.697860, expected=-3.712724
# predicted=0.697860, expected=-2.276828
# predicted=0.697860, expected=-2.425106
# predicted=0.697860, expected=-3.724140
# predicted=0.697860, expected=-2.201361
# predicted=0.697860, expected=0.219312
# predicted=0.697860, expected=0.059324
# predicted=0.697860, expected=0.343528
# predicted=0.697860, expected=1.791931
# predicted=0.697860, expected=0.669353
# predicted=0.697860, expected=-0.505248
# predicted=0.697860, expected=0.118132
# predicted=0.697860, expected=-1.221856
# predicted=0.697860, expected=-1.004347
# predicted=0.697860, expected=-0.470485
# predicted=0.697860, expected=-0.194735
# predicted=0.697860, expected=1.009319
# predicted=0.697860, expected=1.439934
# predicted=0.697860, expected=1.716595
# predicted=0.697860, expected=1.932397
# predicted=0.697860, expected=1.850081
# predicted=0.697860, expected=1.194721
# predicted=0.697860, expected=2.958972
# predicted=0.697860, expected=3.111787
# predicted=0.697860, expected=1.335107
# predicted=0.697860, expected=1.397402
# predicted=0.697860, expected=0.374058
# predicted=0.697860, expected=0.855915
# predicted=0.697860, expected=1.784348
# predicted=0.697860, expected=1.389197
# predicted=0.697860, expected=-0.165867
# predicted=0.697860, expected=-0.531916
# predicted=0.697860, expected=0.007447
# predicted=0.697860, expected=-0.331146

# %%
predictions_df = predictions_df[[0]]
df_val = df_val[["y7"]]
predictions_df.columns

# %%
predictions_df = predictions_df.rename(columns = {0: 'Predicted'}, inplace = False)
df_val = df_val.rename(columns = {"y7": 'Expected'}, inplace = False)

# %%
val_results_df=pd.concat([df_val,predictions_df], axis=1)

# %%
#RMSE bulunması

# %%
döviz - reel faiz (zaman serisi)

# %%
marmara kapital, haydar acun, haberler nasıl etkiliyor. (nlp + zaman serisi)

# %%
döviz kuru oynaklığı ve bist üzerindeki etkisi -- ders projesi
ocak
15
literatür taraması

# %%
pyplot.plot(df_val)
pyplot.plot(predictions_df, color='red')
pyplot.show()

# %%
val_results_df.head()
# Out:
#    Expected  Predicted
# 0  1.002199  -0.611632
# 1  2.787295  -0.611632
# 2  2.051013  -0.611632
# 3  1.989426  -0.611632
# 4  1.909431  -0.611632

# %%
rmse = sqrt(mean_squared_error(df_val, predictions_df))
print('Test RMSE: %.3f' % rmse)


#Test RMSE: 90.986
# Out:
# Test RMSE: 2.447
